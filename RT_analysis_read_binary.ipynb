# %%
import numpy as np
import h5py
from numpy.fft import fft, fftfreq, ifft, rfft
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# %%
# Locate the data stored in the HDF5 groups, and put them into arrays
with h5py.File('water_classical_x_0p0001.bin', 'r') as f_x:
    base_items = list(f_x.items())
    print('Items in the base directory: \n', base_items)
    RT = f_x.get('RT')
    RT_items = list(RT.items())
    print('\n Items in RT: ', RT_items)
    energy_x = np.array(RT.get('ENERGY')) 
    dipole_x = np.array(RT.get('LEN_ELEC_DIPOLE')) 
    time =  np.array(RT.get('TIME'))
# Out:
# Items in the base directory:
#  [('INTS', <HDF5 group "/INTS" (51 members)>), ('RT', <HDF5 group "/RT" (6 members)>), ('SCF', <HDF5 group "/SCF" (14 members)>)]
#
#  Items in RT:  [('ENERGY', <HDF5 dataset "ENERGY": shape (12401,), type "<f8">), ('LEN_ELEC_DIPOLE', <HDF5 dataset "LEN_ELEC_DIPOLE": shape (12401, 3), type "<f8">), ('LEN_ELEC_DIPOLE_FIELD', <HDF5 dataset "LEN_ELEC_DIPOLE_FIELD": shape (12401, 3), type "<f8">), ('TD_1PDM_ORTHO_SCALAR', <HDF5 dataset "TD_1PDM_ORTHO_SCALAR": shape (24, 24), type "<c16">), ('TD_1PDM_SCALAR', <HDF5 dataset "TD_1PDM_SCALAR": shape (24, 24), type "<c16">), ('TIME', <HDF5 dataset "TIME": shape (12401,), type "<f8">)]

# %%
energy_x
# Out:
# array([-76.39678366, -76.39678366, -76.39678366, ..., -76.39678366,
#        -76.39678366, -76.39678366])

# %%
dipole_x
# Out:
# array([[ 1.04360964e-14,  7.66496949e-01, -4.70969557e-14],
#        [-1.09605977e-06,  7.66496949e-01, -4.76684199e-14],
#        [-3.22413054e-06,  7.66496949e-01, -4.72940725e-14],
#        ...,
#        [ 1.85932124e-05,  7.66496948e-01, -6.31332898e-14],
#        [ 1.87966361e-05,  7.66496948e-01, -6.89346549e-14],
#        [ 1.90387038e-05,  7.66496948e-01, -7.06297055e-14]])

# %%
# Locate the data stored in the HDF5 groups, and put them into arrays
with h5py.File('water_classical_y_0p0001.bin', 'r') as f_y:
    base_items = list(f_y.items())
    print('Items in the base directory: \n', base_items)
    RT = f_y.get('RT')
    RT_items = list(RT.items())
    print('\n Items in RT: ', RT_items)
    energy_y = np.array(RT.get('ENERGY')) 
    dipole_y = np.array(RT.get('LEN_ELEC_DIPOLE'))
# Out:
# Items in the base directory:
#  [('INTS', <HDF5 group "/INTS" (51 members)>), ('RT', <HDF5 group "/RT" (6 members)>), ('SCF', <HDF5 group "/SCF" (14 members)>)]
#
#  Items in RT:  [('ENERGY', <HDF5 dataset "ENERGY": shape (12401,), type "<f8">), ('LEN_ELEC_DIPOLE', <HDF5 dataset "LEN_ELEC_DIPOLE": shape (12401, 3), type "<f8">), ('LEN_ELEC_DIPOLE_FIELD', <HDF5 dataset "LEN_ELEC_DIPOLE_FIELD": shape (12401, 3), type "<f8">), ('TD_1PDM_ORTHO_SCALAR', <HDF5 dataset "TD_1PDM_ORTHO_SCALAR": shape (24, 24), type "<c16">), ('TD_1PDM_SCALAR', <HDF5 dataset "TD_1PDM_SCALAR": shape (24, 24), type "<c16">), ('TIME', <HDF5 dataset "TIME": shape (12401,), type "<f8">)]

# %%
energy_y
# Out:
# array([-76.39670701, -76.39678366, -76.39678366, ..., -76.39678366,
#        -76.39678366, -76.39678366])

# %%
dipole_y
# Out:
# array([[ 1.11022302e-14,  7.66496949e-01, -4.63418572e-14],
#        [ 1.02140518e-14,  7.66495827e-01, -4.58569373e-14],
#        [ 9.10382880e-15,  7.66493644e-01, -4.39005664e-14],
#        ...,
#        [-3.55271368e-14,  7.66497911e-01, -5.43989751e-14],
#        [-3.33066907e-14,  7.66497748e-01, -5.77534269e-14],
#        [-2.93098879e-14,  7.66497565e-01, -6.25362944e-14]])

# %%
# Locate the data stored in the HDF5 groups, and put them into arrays
with h5py.File('water_classical_z_0p0001.bin', 'r') as f_z:
    base_items = list(f_z.items())
    print('Items in the base directory: \n', base_items)
    RT = f_z.get('RT')
    RT_items = list(RT.items())
    print('\n Items in RT: ', RT_items)
    energy_z = np.array(RT.get('ENERGY')) 
    dipole_z = np.array(RT.get('LEN_ELEC_DIPOLE'))
# Out:
# Items in the base directory:
#  [('INTS', <HDF5 group "/INTS" (51 members)>), ('RT', <HDF5 group "/RT" (6 members)>), ('SCF', <HDF5 group "/SCF" (14 members)>)]
#
#  Items in RT:  [('ENERGY', <HDF5 dataset "ENERGY": shape (12401,), type "<f8">), ('LEN_ELEC_DIPOLE', <HDF5 dataset "LEN_ELEC_DIPOLE": shape (12401, 3), type "<f8">), ('LEN_ELEC_DIPOLE_FIELD', <HDF5 dataset "LEN_ELEC_DIPOLE_FIELD": shape (12401, 3), type "<f8">), ('TD_1PDM_ORTHO_SCALAR', <HDF5 dataset "TD_1PDM_ORTHO_SCALAR": shape (24, 24), type "<c16">), ('TD_1PDM_SCALAR', <HDF5 dataset "TD_1PDM_SCALAR": shape (24, 24), type "<c16">), ('TIME', <HDF5 dataset "TIME": shape (12401,), type "<f8">)]

# %%
energy_z
# Out:
# array([-76.39678366, -76.39678366, -76.39678366, ..., -76.39678366,
#        -76.39678366, -76.39678366])

# %%
dipole_z
# Out:
# array([[ 9.76996262e-15,  7.66496949e-01, -4.65184639e-14],
#        [ 1.02140518e-14,  7.66496949e-01, -1.18546803e-06],
#        [ 1.37667655e-14,  7.66496949e-01, -3.50254350e-06],
#        ...,
#        [-3.35287353e-14,  7.66496949e-01,  1.23696652e-05],
#        [-1.46549439e-14,  7.66496949e-01,  1.14865659e-05],
#        [-1.15463195e-14,  7.66496949e-01,  1.05309464e-05]])

# %%
# Getting the ground state dipoles
gs_x = dipole_x[0][0]
gs_y = dipole_y[0][1]
gs_z = dipole_z[0][2]

# %%
# Subtracting off the ground state dipoles
D_t_x = np.array([ i[0] - gs_x for i in dipole_x])
D_t_y = np.array([ i[1] - gs_y for i in dipole_y])
D_t_z = np.array([ i[2] - gs_z for i in dipole_z])

# %%
D_t_x
# Out:
# array([ 0.00000000e+00, -1.09605978e-06, -3.22413055e-06, ...,
#         1.85932124e-05,  1.87966361e-05,  1.90387038e-05])

# %%
plt.plot(time, D_t_x)

# %%
# This part is to add the damping factor. I will look into 
# more efficient ways of doing this
x_t_combined = np.vstack((D_t_x, time)).T
y_t_combined = np.vstack((D_t_y, time)).T
z_t_combined = np.vstack((D_t_z, time)).T

damping_factor = 0.01
D_t_x_damped = np.array([ np.exp(-damping_factor*i[1]) * i[0] for i in x_t_combined])
D_t_y_damped = np.array([ np.exp(-damping_factor*i[1]) * i[0] for i in y_t_combined])
D_t_z_damped = np.array([ np.exp(-damping_factor*i[1]) * i[0] for i in z_t_combined])

# %%
time_in_fs = time * 0.02418884254
energy_in_eV = time_in_fs * 4.13567
energy_in_eV
# Out:
# array([0.00000000e+00, 5.00185352e-03, 1.00037070e-02, ...,
#        6.20129800e+01, 6.20179818e+01, 6.20229837e+01])

# %%
n = D_t_x_damped.size
# convert atomic uni|t time to SI unit (fs) 
timestep = 0.05 * 0.02418884254
time_in_fs = np.arange(0, n*timestep, timestep)
time_in_fs[0] = timestep * 0.5
freq = [ 2 * np.pi / i for i in time_in_fs]
E_in_eV = [ 4.13567 * i for i in time_in_fs]
E_in_eV
# Out:
# [0.0025009267606850454,
#  0.005001853521370091,
#  0.010003707042740182,
#  0.015005560564110274,
#  0.020007414085480364,
#  0.025009267606850457,
#  0.030011121128220547,
#  0.035012974649590634,
#  0.04001482817096073,
#  0.04501668169233082,
#  0.050018535213700914,
#  0.055020388735071,
#  0.060022242256441094,
#  0.06502409577781118,
#  0.07002594929918127,
#  0.07502780282055137,
#  0.08002965634192145,
#  0.08503150986329154,
#  0.09003336338466164,
#  0.09503521690603173,
#  0.10003707042740183,
#  0.10503892394877191,
#  0.110040777470142,
#  0.1150426309915121,
#  0.12004448451288219,
#  0.12504633803425227,
#  0.13004819155562236,
#  0.13505004507699245,
#  0.14005189859836253,
#  0.14505375211973262,
#  0.15005560564110274,
#  0.15505745916247282,
#  0.1600593126838429,
#  0.165061166205213,
#  0.17006301972658308,
#  0.1750648732479532,
#  0.18006672676932328,
#  0.18506858029069337,
#  0.19007043381206346,
#  0.19507228733343354,
#  0.20007414085480366,
#  0.20507599437617374,
#  0.21007784789754383,
#  0.21507970141891392,
#  0.220081554940284,
#  0.2250834084616541,
#  0.2300852619830242,
#  0.2350871155043943,
#  0.24008896902576438,
#  0.24509082254713446,
#  0.25009267606850455,
#  0.25509452958987466,
#  0.2600963831112447,
#  0.26509823663261484,
#  0.2701000901539849,
#  0.275101943675355,
#  0.28010379719672507,
#  0.2851056507180952,
#  0.29010750423946524,
#  0.2951093577608354,
#  0.30011121128220547,
#  0.3051130648035756,
#  0.31011491832494564,
#  0.31511677184631576,
#  0.3201186253676858,
#  0.32512047888905593,
#  0.330122332410426,
#  0.33512418593179605,
#  0.34012603945316616,
#  0.3451278929745362,
#  0.3501297464959064,
#  0.35513160001727645,
#  0.36013345353864656,
#  0.3651353070600166,
#  0.37013716058138674,
#  0.3751390141027568,
#  0.3801408676241269,
#  0.38514272114549697,
#  0.3901445746668671,
#  0.39514642818823714,
#  0.4001482817096073,
#  0.40515013523097737,
#  0.4101519887523475,
#  0.41515384227371754,
#  0.42015569579508766,
#  0.4251575493164577,
#  0.43015940283782783,
#  0.4351612563591979,
#  0.440163109880568,
#  0.44516496340193806,
#  0.4501668169233082,
#  0.4551686704446783,
#  0.4601705239660484,
#  4.581697825575003,
#  4.586699679096373,
#  4.591701532617744,
#  4.596703386139113,
#  4.601705239660483,
#  4.606707093181854,
#  4.6117089467032235,
#  4.6167108002245945,
#  4.6217126537459645,
#  4.626714507267334,
#  4.631716360788705,
#  4.636718214310074,
#  4.641720067831444,
#  4.646721921352815,
#  4.651723774874184,
#  4.656725628395555,
#  4.661727481916925,
#  4.666729335438294,
#  4.671731188959665,
#  4.676733042481035,
#  4.681734896002404,
#  4.686736749523775,
#  4.691738603045145,
#  4.696740456566515,
#  4.7017423100878855,
#  4.7067441636092555,
#  4.711746017130626,
#  4.716747870651996,
#  4.721749724173367,
#  4.726751577694736,
#  4.731753431216106,
#  4.736755284737477,
#  4.741757138258846,
#  4.746758991780216,
#  4.751760845301587,
#  4.756762698822956,
#  4.761764552344327,
#  4.766766405865697,
#  4.771768259387066,
#  4.776770112908437,
#  4.781771966429806,
#  4.7867738199511765,
#  4.791775673472547,
#  4.796777526993917,
#  4.8017793805152875,
#  4.806781234036658,
#  4.811783087558027,
#  4.816784941079398,
#  4.821786794600768,
#  4.826788648122138,
#  4.831790501643508,
#  4.836792355164878,
#  4.841794208686248,
#  4.846796062207618,
#  4.851797915728988,
#  4.856799769250358,
#  4.861801622771728,
#  4.866803476293099,
#  4.871805329814468,
#  4.876807183335838,
#  4.881809036857209,
#  4.8868108903785785,
#  4.891812743899949,
#  4.8968145974213195,
#  4.901816450942689,
#  4.90681830446406,
#  4.91182015798543,
#  4.916822011506799,
#  4.92182386502817,
#  4.926825718549539,
#  4.93182757207091,
#  4.93682942559228,
#  4.941831279113649,
#  4.94683313263502,
#  4.95183498615639,
#  4.956836839677759,
#  4.96183869319913,
#  4.9668405467205,
#  4.97184240024187,
#  4.9768442537632405,
#  4.9818461072846105,
#  4.986847960805981,
#  4.991849814327351,
#  4.996851667848721,
#  ...]

# %%
FT_x = np.fft.fft(D_t_x_damped)
D_omega_x = np.fft.fftfreq(n, d=timestep)
D_omega_x

FT_y = np.fft.fft(D_t_y_damped)
D_omega_y = np.fft.fftfreq(n, d=timestep)
D_omega_y
# Out:
# array([ 0.        ,  0.06667426,  0.13334852, ..., -0.20002278,
#        -0.13334852, -0.06667426])

# %%
FT_z.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-8ed52d735db8> in <module>
# ----> 1 FT_z.shape
#
# NameError: name 'FT_z' is not defined

# %%
FT_z = np.fft.fft(D_t_z_damped)
D_omega_z = np.fft.fftfreq(n, d=timestep)
D_omega_z
# Out:
# array([ 0.        ,  0.06667426,  0.13334852, ..., -0.20002278,
#        -0.13334852, -0.06667426])

# %%
figure(figsize=(8, 6), dpi=300)
plt.plot(D_omega_x, FT_x, label = 'FT_x')
plt.plot(D_omega_x, FT_y, label = 'FT_y')
plt.plot(D_omega_x, FT_z, label = 'FT_z')
plt.legend()
#plt.xlim()
# Out:
# /Users/aodongliu/opt/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
abs = []
for i in range(D_omega_x.size):
    signal = (4 * np.pi * D_omega_x[i])/ 3 * (FT_x[i].imag + FT_y[i].imag + FT_z[i].imag)
    abs.append(signal)

# %%
figure(figsize = (8, 6), dpi=300)
plt.plot(energy_in_eV, abs)
plt.xlim(0,1.2)
# Out:
# (0, 1.2)
